# %%
# !curl -L "https://public.roboflow.com/ds/LMVbpbBE7R?key=M8keKhx9gp" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip

# %%
# !git clone https://github.com/ultralytics/ultralytics
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 23785, done.
# remote: Counting objects: 100% (830/830), done.
# remote: Compressing objects: 100% (523/523), done.
# remote: Total 23785 (delta 540), reused 485 (delta 307), pack-reused 22955
# Receiving objects: 100% (23785/23785), 14.27 MiB | 16.29 MiB/s, done.
# Resolving deltas: 100% (16633/16633), done.

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# %cd ultralytics
# Out:
# /content/ultralytics

# %%
# !pip install ultralytics
# Out:
# ...
#   Using cached ultralytics-8.1.42-py3-none-any.whl (749 kB)
# ...
#   Using cached thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...

# %%
# %cd {HOME}
# !yolo task=segment mode=predict model=yolov8s-seg.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg' save=true
# Out:
# /content
# ...
# 100% 22.8M/22.8M [00:00<00:00, 158MB/s]
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# YOLOv8s-seg summary (fused): 195 layers, 11810560 parameters, 0 gradients, 42.6 GFLOPs
#
# ...
# 100% 104k/104k [00:00<00:00, 44.5MB/s]
# image 1/1 /content/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 1 backpack, 1 handbag, 183.4ms
# Speed: 5.6ms preprocess, 183.4ms inference, 637.2ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/segment/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# %cd {HOME}
Image(filename='runs/segment/predict/dog.jpeg', height=600)
# Out:
# /content

# %%
# %cd {HOME}
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Mdpx4BoRewNi4oi7bGkh")
project = rf.workspace("minor-project-2-qrehi").project("coral_segmentation-wdpo7")
version = project.version(9)
dataset = version.download("yolov8")
# Out:
# /content
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 1.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 3.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 13.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 16.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.9.0.80
#     Uninstalling opencv-python-headless-4.9.0.80:
#       Successfully uninstalled opencv-python-headless-4.9.0.80
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
# ...

# %%
# %cd {HOME}
# !yolo task=segment mode=train model=yolov8s-seg.pt data=/content/Coral_Segmentation-9/data.yaml epochs=2 imgsz=640
# Out:
# /content
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...

# %%
# !ls /content/runs/segment/train4/
# Out:
# args.yaml					    labels.jpg	      train_batch2.jpg
# BoxF1_curve.png					    MaskF1_curve.png  val_batch0_labels.jpg
# BoxP_curve.png					    MaskP_curve.png   val_batch0_pred.jpg
# BoxPR_curve.png					    MaskPR_curve.png  val_batch1_labels.jpg
# BoxR_curve.png					    MaskR_curve.png   val_batch1_pred.jpg
# confusion_matrix_normalized.png			    results.csv       val_batch2_labels.jpg
# confusion_matrix.png				    results.png       val_batch2_pred.jpg
# events.out.tfevents.1712296405.aa6babb4ac53.9665.0  train_batch0.jpg  weights
# labels_correlogram.jpg				    train_batch1.jpg

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/segment/train4/confusion_matrix.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/segment/train4/results.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/segment/train4/val_batch0_pred.jpg', width=600)
# Out:
# /content

# %%
# %cd {HOME}

# !yolo task=segment mode=val model={HOME}/runs/segment/train4/weights/best.pt data=/content/Coral_Segmentation-9/data.yaml
# Out:
# /content
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# YOLOv8s-seg summary (fused): 195 layers, 11786566 parameters, 0 gradients, 42.5 GFLOPs
# val: Scanning /content/Coral_Segmentation-9/valid/labels.cache... 156 images, 0 backgrounds, 0 corrupt: 100% 156/156 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 10/10 [00:07<00:00,  1.31it/s]
#                    all        156        275      0.547      0.346      0.363      0.295      0.482      0.342      0.349       0.28
#               Acropora        156          1          0          0    0.00966    0.00544          0          0    0.00966     0.0064
#                Favites        156          7      0.295      0.857      0.432       0.36      0.295      0.857      0.432      0.385
# ...

# %%
# %cd {HOME}
# !yolo task=segment mode=predict model={HOME}/runs/segment/train4/weights/best.pt conf=0.25 source=/content/Coral_Segmentation-9/test/images save=true
# Out:
# /content
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# YOLOv8s-seg summary (fused): 195 layers, 11786566 parameters, 0 gradients, 42.5 GFLOPs
#
# image 1/153 /content/Coral_Segmentation-9/test/images/Image_10_jpg.rf.027dd4e7bd5b74b709cc8ad26b872a82.jpg: 640x640 1 Favites, 13.7ms
# image 2/153 /content/Coral_Segmentation-9/test/images/Image_10_jpg.rf.214140c8a4a24a6a64beade79414f0c2.jpg: 640x640 (no detections), 8.5ms
# image 3/153 /content/Coral_Segmentation-9/test/images/Image_10_jpg.rf.4e78d18088822a64896902f942317acc.jpg: 640x640 1 Favites, 8.1ms
# image 4/153 /content/Coral_Segmentation-9/test/images/Image_10_jpg.rf.575469d0cad41fc40b03cb87370ee6dd.jpg: 640x640 1 Acropora, 9.5ms
# image 5/153 /content/Coral_Segmentation-9/test/images/Image_10_jpg.rf.b1059e1a98a3413350bbd8e288f62cc7.jpg: 640x640 (no detections), 8.6ms
# ...

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'{HOME}/runs/segment/predict2/*.jpg')[:3]:
      display(Image(filename=image_path, height=600))
      print("\n")
